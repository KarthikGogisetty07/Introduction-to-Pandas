# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Loading a tmdb data from kaggle
df = pd.read_csv('tmdb_movies_data.csv')

# %%
df.head()
# Out:
#        id    imdb_id  popularity     budget     revenue  \
# 0  135397  tt0369610   32.985763  150000000  1513528810
# 1   76341  tt1392190   28.419936  150000000   378436354
# 2  262500  tt2908446   13.112507  110000000   295238201
# 3  140607  tt2488496   11.173104  200000000  2068178225
# 4  168259  tt2820852    9.335014  190000000  1506249360
#
#                  original_title  \
# 0                Jurassic World
# 1            Mad Max: Fury Road
# 2                     Insurgent
# 3  Star Wars: The Force Awakens
# 4                     Furious 7
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
# 1  Tom Hardy|Charlize Theron|Hugh Keays-Byrne|Nic...
# 2  Shailene Woodley|Theo James|Kate Winslet|Ansel...
# 3  Harrison Ford|Mark Hamill|Carrie Fisher|Adam D...
# 4  Vin Diesel|Paul Walker|Jason Statham|Michelle ...
#
#                                             homepage          director  \
# ...

# %%
#considering few parameters that are requried!

my_subset = df[['id','popularity', 'original_title', 'genres', 'vote_count', 'vote_average','release_year']]
my_subset.head()
# Out:
#        id  popularity                original_title  \
# 0  135397   32.985763                Jurassic World
# 1   76341   28.419936            Mad Max: Fury Road
# 2  262500   13.112507                     Insurgent
# 3  140607   11.173104  Star Wars: The Force Awakens
# 4  168259    9.335014                     Furious 7
#
#                                       genres  vote_count  vote_average  \
# 0  Action|Adventure|Science Fiction|Thriller        5562           6.5
# 1  Action|Adventure|Science Fiction|Thriller        6185           7.1
# 2         Adventure|Science Fiction|Thriller        2480           6.3
# 3   Action|Adventure|Science Fiction|Fantasy        5292           7.5
# 4                      Action|Crime|Thriller        2947           7.3
#
#    release_year
# 0          2015
# 1          2015
# 2          2015
# 3          2015
# 4          2015

# %%
my_subset.plot(kind='scatter',x='popularity',y='vote_average',color='yellowgreen')
plt.show()

# %%
my_subset.plot(kind='scatter',x='vote_count',y='vote_average',color='purple')
plt.show()

# %%
df1 = my_subset[my_subset['vote_average']>=6]
df1.head()
# Out:
#        id  popularity                original_title  \
# 0  135397   32.985763                Jurassic World
# 1   76341   28.419936            Mad Max: Fury Road
# 2  262500   13.112507                     Insurgent
# 3  140607   11.173104  Star Wars: The Force Awakens
# 4  168259    9.335014                     Furious 7
#
#                                       genres  vote_count  vote_average  \
# 0  Action|Adventure|Science Fiction|Thriller        5562           6.5
# 1  Action|Adventure|Science Fiction|Thriller        6185           7.1
# 2         Adventure|Science Fiction|Thriller        2480           6.3
# 3   Action|Adventure|Science Fiction|Fantasy        5292           7.5
# 4                      Action|Crime|Thriller        2947           7.3
#
#    release_year
# 0          2015
# 1          2015
# 2          2015
# 3          2015
# 4          2015

# %%
df2 = my_subset[my_subset['popularity']>=2]
df2.head()
# Out:
#        id  popularity                original_title  \
# 0  135397   32.985763                Jurassic World
# 1   76341   28.419936            Mad Max: Fury Road
# 2  262500   13.112507                     Insurgent
# 3  140607   11.173104  Star Wars: The Force Awakens
# 4  168259    9.335014                     Furious 7
#
#                                       genres  vote_count  vote_average  \
# 0  Action|Adventure|Science Fiction|Thriller        5562           6.5
# 1  Action|Adventure|Science Fiction|Thriller        6185           7.1
# 2         Adventure|Science Fiction|Thriller        2480           6.3
# 3   Action|Adventure|Science Fiction|Fantasy        5292           7.5
# 4                      Action|Crime|Thriller        2947           7.3
#
#    release_year
# 0          2015
# 1          2015
# 2          2015
# 3          2015
# 4          2015

# %%
### From the graphs the limits for a good movie suggestion based on popularity and vote_average(rating) are selected

# %%
Data = pd.merge(df1, df2)
Data.head()
# Out:
#        id  popularity                original_title  \
# 0  135397   32.985763                Jurassic World
# 1   76341   28.419936            Mad Max: Fury Road
# 2  262500   13.112507                     Insurgent
# 3  140607   11.173104  Star Wars: The Force Awakens
# 4  168259    9.335014                     Furious 7
#
#                                       genres  vote_count  vote_average  \
# 0  Action|Adventure|Science Fiction|Thriller        5562           6.5
# 1  Action|Adventure|Science Fiction|Thriller        6185           7.1
# 2         Adventure|Science Fiction|Thriller        2480           6.3
# 3   Action|Adventure|Science Fiction|Fantasy        5292           7.5
# 4                      Action|Crime|Thriller        2947           7.3
#
#    release_year
# 0          2015
# 1          2015
# 2          2015
# 3          2015
# 4          2015

# %%
Data.sort_values('vote_average', ascending = False).head(10)
# Out:
#          id  popularity            original_title  \
# 237     278    7.192039  The Shawshank Redemption
# 373     238    5.738034             The Godfather
# 84   244786    4.780419                  Whiplash
# 478     424    2.377288          Schindler's List
# 457     240    3.264571    The Godfather: Part II
# 236     680    8.093754              Pulp Fiction
# 238      13    6.715966              Forrest Gump
# 189     155    8.466668           The Dark Knight
# 166     550    8.947905                Fight Club
# 66   157336   24.949134              Interstellar
#
#                               genres  vote_count  vote_average  release_year
# 237                      Drama|Crime        5754           8.4          1994
# 373                      Drama|Crime        3970           8.3          1972
# 84                       Drama|Music        2372           8.2          2014
# 478                Drama|History|War        2632           8.1          1993
# ...

# %%
Genre=input("Enter Your genre >> ")
Genre=Genre.capitalize()
# Out:
# Enter Your genre >> thriller

# %%
Suggested = Data[Data['genres'].str.contains(Genre)]
Suggested.sort_values('vote_average', ascending = False).head()
# Out:
#          id  popularity      original_title                       genres  \
# 189     155    8.466668     The Dark Knight  Drama|Action|Crime|Thriller
# 236     680    8.093754        Pulp Fiction               Thriller|Crime
# 473     539    2.610362              Psycho        Drama|Horror|Thriller
# 408     629    3.440238  The Usual Suspects         Drama|Crime|Thriller
# 73   205596    8.110711  The Imitation Game   History|Drama|Thriller|War
#
#      vote_count  vote_average  release_year
# 189        8432           8.1          2008
# 236        5343           8.1          1994
# 473        1180           8.0          1960
# 408        1942           8.0          1995
# 73         3478           8.0          2014

# %%
## THE PERSON CAN SELECT HIS CHOISE FROM THE TOP 5 MOVIES ACCORDING TO HIS GENRE he entered!!
